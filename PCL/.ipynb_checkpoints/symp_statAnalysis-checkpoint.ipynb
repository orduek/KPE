# %% [markdown]
# ## Statistical analysis of symptom's change

# %%
# %config Completer.use_jedi = False
import pymc3 as pm
import numpy as np
import pandas as pd
import statsmodels
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import preprocessing
import arviz as az
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.10, the latest is 0.3.12.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
# load file
df = pd.read_csv('KPE_bdi_pcl.csv') 
df.head()
# Out:
#    scr_id  scr_dem_gender  scr_dem_age       redcap_event_name_y  pcl5_1  \
# 0  KPE008             1.0         51.0  screening_selfrepo_arm_1     2.0
# 1  KPE008             1.0         51.0             visit_1_arm_1     3.0
# 2  KPE008             1.0         51.0  visit_7_week_follo_arm_1     4.0
# 3  KPE008             1.0         51.0  30_day_follow_up_s_arm_1     4.0
# 4  KPE008             1.0         51.0  90_day_follow_up_s_arm_1     2.0
#
#    pcl5_2  pcl5_3  pcl5_4  pcl5_5  pcl5_6  ...  bdi_14_worthlessness  \
# 0     1.0     1.0     4.0     4.0     4.0  ...                   3.0
# 1     1.0     1.0     4.0     4.0     4.0  ...                   3.0
# 2     2.0     1.0     4.0     4.0     4.0  ...                   3.0
# 3     3.0     1.0     4.0     4.0     1.0  ...                   3.0
# 4     2.0     1.0     2.0     3.0     3.0  ...                   3.0
#
#    bdi_15_lossofenergy  bdi_16_sleepingpattern  bdi_17_irritability  \
# 0                  3.0                     3.0                  3.0
# 1                  3.0                     3.0                  3.0
# 2                  3.0                     3.0                  3.0
# 3                  4.0                     7.0                  4.0
# 4                  4.0                     4.0                  1.0
#
#    bdi_18_changesinappetite  bdi_19_concentrationdiff  \
# 0                       4.0                       3.0
# 1                       4.0                       4.0
# 2                       2.0                       3.0
# 3                       4.0                       4.0
# 4                       2.0                       4.0
#
#    bdi_20_tirednessfatigue  bdi_21_interestinsex  bdi_total  med_cond
# 0                      3.0                   2.0       57.0       Ket
# 1                      3.0                   2.0       54.0       Ket
# 2                      3.0                   3.0       52.0       Ket
# 3                      4.0                   3.0       69.0       Ket
# 4                      4.0                   1.0       51.0       Ket
#
# [5 rows x 48 columns]

# %%
# change names of redcap_enet_name_y
categories_old = ['screening_selfrepo_arm_1', 'visit_1_arm_1','visit_7_week_follo_arm_1',
                  '30_day_follow_up_s_arm_1', '90_day_follow_up_s_arm_1']
categoriesNew=['screen','beforeTrt','afterTrt','FU30','FU90']
cat = pd.Categorical(df.redcap_event_name_y, categories=categories_old)
# set new variable with new categories names
df['time'] = cat.rename_categories(categoriesNew)
df = df.drop('redcap_event_name_y', axis=1) # remove old naming

# %%
# remove 90-days (not enough subjects)
df = df[(df.time!='FU90') & (df.time!='screen')]
# generate for something else
df_med = df[(df.time=='beforeTrt')][['scr_id','med_cond']]
df_med
# Out:
#       scr_id med_cond
# 1     KPE008      Ket
# 6    KPE1223      Ket
# 11   KPE1253      Mid
# 15   KPE1263      Mid
# 20   KPE1293      Ket
# 25   KPE1307      Ket
# 30   KPE1315      Ket
# 33   KPE1322      Ket
# 38   KPE1339      Ket
# 43   KPE1343      Ket
# 48   KPE1351      Mid
# 53   KPE1356      Mid
# 58   KPE1364      Mid
# 63   KPE1369      Mid
# 68   KPE1387      Ket
# 73   KPE1390      Mid
# 78   KPE1403      Mid
# 83   KPE1419      Ket
# 92   KPE1468      Mid
# 96   KPE1480      Mid
# 100  KPE1499      Ket
# 104  KPE1561      Mid
# 109  KPE1573      Ket
# 114  KPE1578      Mid
# 119  KPE1587      Ket
# 123  KPE1612      Mid

# %% [markdown]
# ## Descriptives

# %%
df_clean = df[['scr_id','med_cond','time','pcl5_total']]
# remove screening timepoint - its redundant here
df_clean = df_clean[df_clean.time!='screen'] 
# recategorize time because we removed something
df_clean.time = pd.Categorical(df_clean.time, categories=['beforeTrt','afterTrt','FU30'])
wideDf = df_clean.pivot(index=['scr_id'], columns=['time'], values=['pcl5_total'])
#
wideDf = wideDf.pcl5_total
wideDf = wideDf.merge(df_med, left_on='scr_id', right_on='scr_id', how='outer')
wideDf
sns.pairplot(wideDf, hue="med_cond")

# %%
## check changes in symtpoms
wideDf['delta30'] = wideDf.FU30 - wideDf.beforeTrt
print(f'Number of participants improving 5 points or more is {len(wideDf[wideDf.delta30<=-5])}')
print(f'Number of participants improving 10 points or more is {len(wideDf[wideDf.delta30<=-10])}')
# Out:
# Number of participants improving 5 points or more is 15
# Number of participants improving 10 points or more is 14

# %%
wideDf[['beforeTrt','afterTrt','FU30','med_cond']].describe()
# Out:
#        beforeTrt   afterTrt       FU30
# count  23.000000  25.000000  24.000000
# mean   46.608696  33.840000  30.791667
# std    13.354397  18.372715  15.797576
# min    12.000000   3.000000   4.000000
# 25%    38.000000  20.000000  19.000000
# 50%    48.000000  31.000000  33.000000
# 75%    55.000000  50.000000  45.250000
# max    69.000000  65.000000  56.000000

# %%
# need to scale pcl variable
df_clean['pcl5_total_scaled'] = preprocessing.scale(df_clean.pcl5_total)
df_clean.describe().round(3)
# Out:
#        pcl5_total  pcl5_total_scaled
# count      72.000             72.000
# mean       36.903             -0.000
# std        17.224              1.007
# min         3.000             -1.982
# 25%        21.000             -0.930
# 50%        39.500              0.152
# 75%        50.250              0.780
# max        69.000              1.877

# %%
## Start with simple GLM models (using statsmodel)
glm = smf.mixedlm('pcl5_total_scaled ~ time + med_cond', data=df_clean, groups = df_clean.scr_id, 
                 missing='drop')
model1 = glm.fit()
print(model1.summary())
# Out:
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:            MixedLM Dependent Variable: pcl5_total_scaled
# No. Observations: 72      Method:             REML
# No. Groups:       27      Scale:              0.3178
# Min. group size:  2       Log-Likelihood:     -85.8317
# Max. group size:  3       Converged:          Yes
# Mean group size:  2.7
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.660    0.249  2.651 0.008  0.172  1.148
# time[T.afterTrt]     -0.720    0.167 -4.312 0.000 -1.048 -0.393
# time[T.FU30]         -1.011    0.170 -5.954 0.000 -1.344 -0.678
# med_cond[T.Mid]      -0.167    0.326 -0.512 0.608 -0.805  0.471
# Group Var             0.592    0.452
# ===============================================================

# %%
# so in simple mixed model we see effect for time after treatment and in 30 and 90 days follow-up
# use pinguoin for ANOVA of the mixed model
pg.mixed_anova(data=df_clean, dv='pcl5_total', within='time', between='med_cond', subject='scr_id').round(3)
# Out:
#         Source        SS  DF1  DF2        MS       F  p-unc    np2    eps
# 0     med_cond   219.084    1   20   219.084   0.389  0.540  0.019    NaN
# 1         time  2451.523    2   40  1225.761  19.363  0.000  0.492  0.949
# 2  Interaction   164.615    2   40    82.308   1.300  0.284  0.061    NaN

# %% [markdown]
# ## Go Bayes
# - Organize indexes and define model
# - Try with/without hyperpriors

# %%
# set groups as 0 and 1
group = {'Ket': 1,'Mid': 0} 
df_clean['groupIdx'] =[group[item] for item in df_clean.med_cond] 
# set all the rest
df_clean['scr_id'] = df_clean.scr_id.astype('category')
sub_idx = df_clean.scr_id.cat.codes.values # get county category index values (613 x 1) vec with nums [0-7]
print(sub_idx)
n_subs = len(np.unique(df_clean.scr_id))
print(n_subs)
# set time as index also
#df_clean.groupIdx = pd.Categorical(df_clean.groupIdx)
df_clean.time = pd.Categorical(df_clean.time, 
                    categories=['beforeTrt','afterTrt','FU30'])
timeIDX = df_clean.time.cat.codes.values
print(timeIDX)
# Out:
# [ 0  0  0  1  1  1  2  2  2  3  3  3  4  4  4  5  5  5  6  6  7  7  7  8
#   8  8  9  9  9 10 10 10 11 11 11 12 12 12 13 13 13 14 14 14 15 15 15 16
#  16 16 17 17 17 18 18 19 19 20 20 21 21 21 22 22 22 23 23 23 24 24 24 25
#  25 25 26 26 26]
# 27
# [0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 0 1
#  2 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2 1 2 0 1 0 1 0 1 2 0 1 2 0 1 2 0 1 2 0 1 2
#  0 1 2]

# %%
# lets define our own model using pymc3
with pm.Model() as model1:
  
    
    a = pm.Normal('a', mu=0, sd=1, shape=n_subs)
       
    b = pm.Normal('b', mu=0, sd=1, shape=3) # time
    
    bMed = pm.Normal('bMed', mu=0, sd=.5) # two groups
  
    # Model error
    eps = pm.HalfCauchy('eps', 3)

    y_hat = a[sub_idx] + b[timeIDX] + bMed*df_clean.groupIdx 

    # Data likelihood
    likelihood = pm.Normal('likelihood', mu=y_hat,
                           sigma=eps, observed=df_clean.pcl5_total_scaled)
    prior_checks = pm.sample_prior_predictive(samples=100, random_seed=123)
    trace = pm.sample(draws=2000, tune=2000, target_accept=0.9, return_inferencedata=False)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [likelihood_missing, eps, bMed, b, a]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:13<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 13 seconds.
# The number of effective samples is smaller than 25% for some parameters.

# %%
sns.displot(prior_checks['bMed'])

# %%
az.summary(trace)
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/arviz/data/io_pymc3.py:100: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#                         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# a[0]                   1.080  0.390   0.363    1.819      0.006    0.005
# a[1]                   0.337  0.388  -0.417    1.032      0.006    0.004
# a[2]                   0.798  0.386   0.113    1.549      0.006    0.004
# a[3]                   0.673  0.383  -0.039    1.390      0.006    0.004
# a[4]                  -1.117  0.394  -1.855   -0.368      0.006    0.005
# a[5]                   0.375  0.385  -0.345    1.095      0.006    0.004
# a[6]                  -0.933  0.439  -1.762   -0.102      0.006    0.004
# a[7]                   0.040  0.388  -0.729    0.726      0.006    0.004
# a[8]                   1.132  0.452   0.265    1.958      0.007    0.005
# a[9]                  -0.627  0.393  -1.392    0.101      0.006    0.004
# a[10]                 -0.112  0.377  -0.852    0.567      0.006    0.004
# a[11]                  1.097  0.386   0.357    1.804      0.006    0.004
# a[12]                  0.588  0.386  -0.149    1.295      0.006    0.005
# a[13]                  0.396  0.383  -0.296    1.151      0.006    0.005
# a[14]                  0.703  0.433  -0.096    1.540      0.006    0.005
# a[15]                 -0.893  0.437  -1.739   -0.096      0.007    0.005
# a[16]                 -1.568  0.384  -2.295   -0.845      0.006    0.005
# a[17]                 -0.295  0.393  -1.021    0.438      0.006    0.004
# a[18]                 -0.775  0.437  -1.630    0.026      0.006    0.005
# a[19]                 -0.543  0.431  -1.357    0.280      0.006    0.005
# a[20]                 -0.390  0.438  -1.174    0.463      0.006    0.005
# a[21]                  0.672  0.441  -0.119    1.539      0.007    0.005
# a[22]                 -0.431  0.382  -1.127    0.302      0.006    0.004
# a[23]                 -0.503  0.395  -1.250    0.248      0.006    0.004
# a[24]                 -0.362  0.380  -1.094    0.316      0.006    0.005
# a[25]                  0.250  0.441  -0.590    1.058      0.006    0.004
# a[26]                  0.237  0.379  -0.464    0.950      0.006    0.004
# b[0]                   0.526  0.260   0.066    1.030      0.006    0.004
# b[1]                  -0.182  0.259  -0.687    0.288      0.006    0.004
# b[2]                  -0.474  0.263  -0.952    0.036      0.006    0.004
# bMed                   0.100  0.309  -0.484    0.664      0.007    0.005
# likelihood_missing[0]  1.767  0.716   0.463    3.144      0.007    0.005
# likelihood_missing[1]  1.327  0.691   0.067    2.654      0.007    0.005
# likelihood_missing[2] -0.366  0.710  -1.664    0.985      0.007    0.007
# likelihood_missing[3]  0.588  0.693  -0.664    1.938      0.007    0.006
# likelihood_missing[4]  0.170  0.701  -1.101    1.529      0.007    0.007
# eps                    0.572  0.062   0.464    0.689      0.001    0.001
#
#                        ess_bulk  ess_tail  r_hat
# a[0]                     3669.0    5340.0    1.0
# a[1]                     3911.0    4564.0    1.0
# a[2]                     3855.0    5104.0    1.0
# a[3]                     3818.0    5518.0    1.0
# a[4]                     3760.0    4272.0    1.0
# a[5]                     4071.0    5058.0    1.0
# a[6]                     4871.0    5068.0    1.0
# a[7]                     4155.0    5519.0    1.0
# a[8]                     4622.0    5621.0    1.0
# a[9]                     4061.0    5141.0    1.0
# a[10]                    3634.0    5406.0    1.0
# a[11]                    3699.0    5221.0    1.0
# a[12]                    3584.0    4843.0    1.0
# a[13]                    3570.0    4481.0    1.0
# a[14]                    4450.0    5635.0    1.0
# a[15]                    4239.0    5619.0    1.0
# a[16]                    3626.0    4992.0    1.0
# a[17]                    4134.0    5419.0    1.0
# a[18]                    4978.0    4948.0    1.0
# a[19]                    4525.0    5405.0    1.0
# a[20]                    4660.0    5257.0    1.0
# a[21]                    4560.0    5413.0    1.0
# a[22]                    3682.0    4952.0    1.0
# a[23]                    4154.0    4286.0    1.0
# a[24]                    3667.0    4499.0    1.0
# a[25]                    4941.0    5856.0    1.0
# a[26]                    3817.0    4753.0    1.0
# b[0]                     1831.0    3556.0    1.0
# b[1]                     1801.0    3270.0    1.0
# b[2]                     1829.0    3461.0    1.0
# bMed                     2242.0    3530.0    1.0
# likelihood_missing[0]   11103.0    6134.0    1.0
# likelihood_missing[1]    9987.0    6402.0    1.0
# likelihood_missing[2]   11049.0    6369.0    1.0
# likelihood_missing[3]    9102.0    6253.0    1.0
# likelihood_missing[4]   11378.0    6371.0    1.0
# eps                      5368.0    5822.0    1.0

# %%
az.plot_trace(trace)
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/arviz/data/io_pymc3.py:100: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'a'}>],
#        [<AxesSubplot:title={'center':'b'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'bMed'}>,
#         <AxesSubplot:title={'center':'bMed'}>],
#        [<AxesSubplot:title={'center':'likelihood_missing'}>,
#         <AxesSubplot:title={'center':'likelihood_missing'}>],
#        [<AxesSubplot:title={'center':'eps'}>,
#         <AxesSubplot:title={'center':'eps'}>]], dtype=object)

# %%
with model1:
    ppc = pm.sample_posterior_predictive(
        trace, random_seed=124
    )
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:11<00:00]
#     </div>

# %%
# calculate difference between before/after
afterDiff = trace["b"][:,1] - trace["b"][:,0]
sns.distplot(afterDiff)
# lets see what are the chances of no difference or more than zero
sum(afterDiff[1000:]>=0) / len(afterDiff[1000:])  # no chance so significant difference
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.0

# %%
# lets test for 30 days F/U
Diff30 = trace["b"][:, 2] - trace["b"][:, 0]
sns.distplot(Diff30)
# lets see what are the chances of no difference or more than zero
sum(Diff30>=0) / len(Diff30[:])
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.0

# %%
sns.distplot(trace["b"][:-1000,0], color = 'blue', label='before')
sns.distplot(trace["b"][:-1000,1], color = 'orange', label = 'after')
sns.distplot(trace["b"][:-1000,2], color = 'green', label = '30Days')
plt.legend()
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# test the same on group
#groupDiff = trace['bMed'][:,1] - trace['bMed'][:,0]
sns.distplot(trace["bMed"])
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Plotting

# %%
## Plot symtpoms
sns.set_style("whitegrid")
ax = sns.catplot('time','pcl5_total', data=df_clean, kind='point', ci=68, n_boot=5000,
           set_ylabel=("Total PCL5 score"))
ax.set_ylabels("Total PCL5 score")
ax.set_xlabels("Time of Assesment")
ax.savefig("SymtpomsChange.png", dpi=300)
# Out:
# /gpfs/ysm/project/joormann/oad4/conda_envs/neuroAnalysis/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
